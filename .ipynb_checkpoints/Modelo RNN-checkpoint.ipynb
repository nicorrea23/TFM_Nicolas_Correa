# %% [markdown]
# # Ejercicio Resuelto: RNN y sus aplicaciones en las series temporales
#
# En esta actividad se va a aplicar el conocimiento adquirido sobre las RNN para entrenar modelos que sean capaces de predecir el comportamiento de las series temporales. Para ello, se usará un dataset de temperaturas para mediante la aplicación de RNN, predecir los valores futuros que tendrá la serie temporal que se tiene. Este trabajo se suele hacer mediante modelos ARIMA, pero en esta práctica se verá cómo el modelado mediante RNN es una opción muy buena en estos casos de series temporales.

# %% [markdown]
# **1. Descargar el dataset y almacenarlo**
#
# En primer lugar hay que importar tensorflow.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.8.2

# %% [markdown]
# El siguiente paso es importar las bibliotecas numpy y matplotlib. Además, se define el método **plot_series** que se utilizará para hacer las gráficas de las series temporales.

# %%
import numpy as np
import matplotlib.pyplot as plt
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

# %% [markdown]
# A continuación se descarga el dataset de las temperaturas mínimas diarias.

# %%
# !wget --no-check-certificate \
    https://raw.githubusercontent.com/jbrownlee/Datasets/master/daily-min-temperatures.csv \
    -O /tmp/daily-min-temperatures.csv
# Out:
# --2022-06-07 10:36:08--  https://raw.githubusercontent.com/jbrownlee/Datasets/master/daily-min-temperatures.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 67921 (66K) [text/plain]
# Saving to: ‘/tmp/daily-min-temperatures.csv’
#
# /tmp/daily-min-temp 100%[===================>]  66.33K  --.-KB/s    in 0.01s
#
# 2022-06-07 10:36:08 (4.43 MB/s) - ‘/tmp/daily-min-temperatures.csv’ saved [67921/67921]

# %% [markdown]
# En este paso, se utilizará la biblioteca csv de Python para guardar y poder leer el dataset de temperaturas mínimas diarias que ha sido descargado en el paso anterior. Además, se construye la variable **series** que será donde se guarde la serie temporal. Por último, siempre que se trate con una serie temporal, es una buena práctica hacer un gráfico para poder verla y tener una idea de cómo es.

# %%
import csv
time_step = []
temps = []

with open('/tmp/daily-min-temperatures.csv') as csvfile:
  reader = csv.reader(csvfile, delimiter=',')
  next(reader)
  step=0
  for row in reader:
    temps.append(float(row[1]))
    time_step.append(step)
    step = step + 1

series = np.array(temps)
time = np.array(time_step)
plt.figure(figsize=(10, 6))
plot_series(time, series)

# %% [markdown]
# # 2. Creación de las variables necesarias para el diseño de la red neuronal

# %% [markdown]
# Una técnica muy común cuando se trata con series temporales es utilizar una ventana temporal que se vaya desplazando sobre la serie temporal para reducir su análisis a lo que ocurre en ese ventana de forma local, para a continuación realizar el modelado global.
#
# **Ejercicio 1 (0.4 puntos)**: Crear las variables de entrenamiento y validación y hacer la partición de las mismas. Las variables que hay que crear son:
#
# *   time_train
# *   x_train
# *   time_valid
# *   x_valid

# %%
## variables para la técnica de la ventana temporal
split_time = 2500
window_size = 30
batch_size = 32
shuffle_buffer_size = 1000

## Split del dataset en entrenamiento y validación
time_train = time[:split_time]
x_train = series[:split_time]
time_valid = time[split_time:]
x_valid = series[split_time:]

# %% [markdown]
# 2. Creación del método **windowed_datset** para poder utilizarlo en el modelo. Las entradas por parámetros del método son:
#
# *   series
# *   window_size
# *   batch_size
# *   shuffle_buffer
#
# El resto de elementos que se usan para construir la función ventana temporal para explorar el dataset, son métodos de Python para tratar con series temporales.

# %% [markdown]
# # 3. Diseño de la función para predecir los siguientes valores de la serie temporal usando la técnica de la ventana temporal

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    ds = ds.shuffle(shuffle_buffer)
    ds = ds.map(lambda w: (w[:-1], w[1:]))
    return ds.batch(batch_size).prefetch(1)

# %% [markdown]
# A continuación, y usando como modelo el método **windowed_dataset** se procederá a adaptar el método **model_forecast** que se usará para predecir los siguientes valores de la serie temporal utilizando la técnica de la ventana temporal.
#
# **Ejercicio 2 (1.6 puntos)**: completar el método model_forecast creando los elementos necesarios dentro del método:
#
# 1.   Crear la variable **ds** y darle el valor resultante del método **from_tensor_slices** pasando por parametro **series** **(0.4 puntos)**
# 2.   Actualizar la ventana (**window**) de la variable **ds** (nota: en este caso el tamaño es el mismo de la ventana, no es necesario que sea window_size+1) **(0.4 puntos)**
# 3.   Crear el **flat_map** de la variable, teniendo en cuenta que el tamaño es **window_size** **(0.4 puntos)**
# 4.   Añadir la siguiente linea de código: ds = ds.batch(32).prefetch(1)
# 5.   Crear la variable **forecast** en la que se usará el método **predict** **(0.4 puntos)**
# 6.   Por último, se devolverá la variable forecast.

# %%
def model_forecast(model, series, window_size):
  ds = tf.data.Dataset.from_tensor_slices(series)
  ds = ds.window(window_size, shift=1, drop_remainder=True)
  ds = ds.flat_map(lambda w: w.batch(window_size))
  ds = ds.batch(32).prefetch(1)
  forecast = model.predict(ds)
  return forecast

# %% [markdown]
# A continuación, se limpia la sesión de keras, y se inicializan las variables necesarias para poder diseñar el modelo de series temporales a entrenar usando RNN.

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(51)
np.random.seed(51)
window_size = 64
batch_size = 256

# %% [markdown]
# # 4. Diseño de la red neuronal

# %% [markdown]
# **Ejercicio 3.1 (0.5 puntos)**: Hay que crear la variable **train_set** dandole el valor que se reciba del método **windowed_datset**, los parametros que debe recibir este método son: **x_train, window_size, batch_size, shuffle_buffer_size**

# %%
train_set = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)

# %% [markdown]
# **Ejercicio 3.2 (4 puntos)**: Se debe construir la red neuronal de aprendizaje profunda basada para modelar la serie temporal de las temperaturas minimas diarias. Esta red neuronal debera contar con las siguientes capas ocultas:
#
# 1.   Una capa de convolución en una dimensión que tenga 32 filtros, una tamaño del kernel de 5, un stride de 1, padding "causal", la función de activación debe ser relu y el input shape debe ser [None, 1]
# 2.   Una capa LSTM con 64 neuronas y retorno de secuencias
# 3.   Una capa LSTM con 64 neuronas y retorno de secuencias
# 4.   Una capa densa con 30 neuronas
# 5.   Una capa densa con 10 neuronas
# 6.   Una capa densa con 1 neuronas
# 7.   Por último, se añade la siguiente capa: tf.keras.layers.Lambda(lambda x: x * 400)

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv1D(filters=32, kernel_size=5,
                      strides=1, padding="causal",
                      activation="relu",
                      input_shape=[None, 1]),
  tf.keras.layers.LSTM(64, return_sequences=True),
  tf.keras.layers.LSTM(64, return_sequences=True),
  tf.keras.layers.Dense(30),
  tf.keras.layers.Dense(10),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 400)
])

# %% [markdown]
# # 5. Entrenamiento de la red neuronal

# %% [markdown]
# **Ejercicio 4 (0.5 puntos)**: Se va a diseñar un método callbacks para el learning rate que será guardado en la variable **lr_schedule**, este método deberá usar el método **LearningRateScheduler** de Python y será una función **lambda** que le de el valor a epoch de 1e-8 * 10**(epoch / 20) ****

# %%
lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-8 * 10 * (epoch / 20), verbose=1)

# %% [markdown]
# **Ejercicio 5 (1.5 puntos):** Compilar la red neuronal con los siguientes parametros:
#
# *   loss: método Huber de keras
# *   El optimizador debe ser el SGD con learning rate 1e-8 y momentum 0.9
# *   La métrica a visualizar es el error absoluto medio (medium absolute error en ingles)

# %%
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=tf.keras.optimizers.SGD(learning_rate=1e-8, momentum=0.9),
              metrics=["mae"])

# %% [markdown]
# Para terminar se entrena el modelo previamente diseñado y compilado en los pasos anteriores.

# %%
history = model.fit(train_set, epochs=100, callbacks=[lr_schedule])
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.0.
# Epoch 1/100
# 10/10 [==============================] - 15s 684ms/step - loss: 115.2319 - mae: 115.7314 - lr: 0.0000e+00
#
# Epoch 2: LearningRateScheduler setting learning rate to 5e-09.
# Epoch 2/100
# 10/10 [==============================] - 3s 305ms/step - loss: 114.4768 - mae: 114.9763 - lr: 5.0000e-09
#
# Epoch 3: LearningRateScheduler setting learning rate to 1e-08.
# Epoch 3/100
# 10/10 [==============================] - 3s 307ms/step - loss: 110.0414 - mae: 110.5410 - lr: 1.0000e-08
#
# Epoch 4: LearningRateScheduler setting learning rate to 1.5e-08.
# Epoch 4/100
# 10/10 [==============================] - 3s 308ms/step - loss: 100.4675 - mae: 100.9673 - lr: 1.5000e-08
#
# Epoch 5: LearningRateScheduler setting learning rate to 2e-08.
# Epoch 5/100
# 10/10 [==============================] - 3s 303ms/step - loss: 85.6456 - mae: 86.1454 - lr: 2.0000e-08
#
# Epoch 6: LearningRateScheduler setting learning rate to 2.5e-08.
# Epoch 6/100
# 10/10 [==============================] - 3s 309ms/step - loss: 66.1414 - mae: 66.6413 - lr: 2.5000e-08
#
# Epoch 7: LearningRateScheduler setting learning rate to 3e-08.
# Epoch 7/100
# 10/10 [==============================] - 3s 306ms/step - loss: 42.4927 - mae: 42.9922 - lr: 3.0000e-08
#
# Epoch 8: LearningRateScheduler setting learning rate to 3.4999999999999996e-08.
# Epoch 8/100
# 10/10 [==============================] - 3s 305ms/step - loss: 19.6585 - mae: 20.1528 - lr: 3.5000e-08
#
# Epoch 9: LearningRateScheduler setting learning rate to 4e-08.
# Epoch 9/100
# 10/10 [==============================] - 3s 305ms/step - loss: 16.9672 - mae: 17.4618 - lr: 4.0000e-08
#
# Epoch 10: LearningRateScheduler setting learning rate to 4.5e-08.
# Epoch 10/100
# 10/10 [==============================] - 5s 430ms/step - loss: 15.6048 - mae: 16.0988 - lr: 4.5000e-08
#
# Epoch 11: LearningRateScheduler setting learning rate to 5e-08.
# Epoch 11/100
# 10/10 [==============================] - 3s 303ms/step - loss: 13.8352 - mae: 14.3266 - lr: 5.0000e-08
#
# Epoch 12: LearningRateScheduler setting learning rate to 5.5e-08.
# Epoch 12/100
# 10/10 [==============================] - 3s 305ms/step - loss: 12.9234 - mae: 13.4140 - lr: 5.5000e-08
#
# Epoch 13: LearningRateScheduler setting learning rate to 6e-08.
# Epoch 13/100
# 10/10 [==============================] - 3s 303ms/step - loss: 12.0294 - mae: 12.5201 - lr: 6.0000e-08
#
# Epoch 14: LearningRateScheduler setting learning rate to 6.5e-08.
# Epoch 14/100
# 10/10 [==============================] - 3s 309ms/step - loss: 11.2484 - mae: 11.7385 - lr: 6.5000e-08
#
# Epoch 15: LearningRateScheduler setting learning rate to 6.999999999999999e-08.
# Epoch 15/100
# 10/10 [==============================] - 3s 308ms/step - loss: 10.5918 - mae: 11.0813 - lr: 7.0000e-08
#
# Epoch 16: LearningRateScheduler setting learning rate to 7.5e-08.
# Epoch 16/100
# 10/10 [==============================] - 3s 305ms/step - loss: 10.0487 - mae: 10.5374 - lr: 7.5000e-08
#
# Epoch 17: LearningRateScheduler setting learning rate to 8e-08.
# Epoch 17/100
# 10/10 [==============================] - 3s 310ms/step - loss: 9.6081 - mae: 10.0960 - lr: 8.0000e-08
#
# Epoch 18: LearningRateScheduler setting learning rate to 8.5e-08.
# Epoch 18/100
# 10/10 [==============================] - 3s 309ms/step - loss: 9.2523 - mae: 9.7403 - lr: 8.5000e-08
#
# Epoch 19: LearningRateScheduler setting learning rate to 9e-08.
# Epoch 19/100
# 10/10 [==============================] - 3s 310ms/step - loss: 8.9521 - mae: 9.4398 - lr: 9.0000e-08
#
# Epoch 20: LearningRateScheduler setting learning rate to 9.499999999999999e-08.
# Epoch 20/100
# 10/10 [==============================] - 4s 317ms/step - loss: 8.6864 - mae: 9.1737 - lr: 9.5000e-08
#
# Epoch 21: LearningRateScheduler setting learning rate to 1e-07.
# Epoch 21/100
# 10/10 [==============================] - 3s 310ms/step - loss: 8.4451 - mae: 8.9323 - lr: 1.0000e-07
#
# Epoch 22: LearningRateScheduler setting learning rate to 1.05e-07.
# Epoch 22/100
# 10/10 [==============================] - 4s 390ms/step - loss: 8.2207 - mae: 8.7075 - lr: 1.0500e-07
#
# Epoch 23: LearningRateScheduler setting learning rate to 1.1e-07.
# Epoch 23/100
# 10/10 [==============================] - 3s 310ms/step - loss: 8.0118 - mae: 8.4983 - lr: 1.1000e-07
#
# Epoch 24: LearningRateScheduler setting learning rate to 1.1499999999999998e-07.
# Epoch 24/100
# 10/10 [==============================] - 4s 321ms/step - loss: 7.8166 - mae: 8.3030 - lr: 1.1500e-07
#
# Epoch 25: LearningRateScheduler setting learning rate to 1.2e-07.
# Epoch 25/100
# 10/10 [==============================] - 3s 312ms/step - loss: 7.6333 - mae: 8.1196 - lr: 1.2000e-07
#
# Epoch 26: LearningRateScheduler setting learning rate to 1.25e-07.
# Epoch 26/100
# 10/10 [==============================] - 3s 309ms/step - loss: 7.4632 - mae: 7.9492 - lr: 1.2500e-07
#
# Epoch 27: LearningRateScheduler setting learning rate to 1.3e-07.
# Epoch 27/100
# 10/10 [==============================] - 3s 308ms/step - loss: 7.2997 - mae: 7.7855 - lr: 1.3000e-07
#
# Epoch 28: LearningRateScheduler setting learning rate to 1.35e-07.
# Epoch 28/100
# 10/10 [==============================] - 3s 309ms/step - loss: 7.1493 - mae: 7.6345 - lr: 1.3500e-07
#
# Epoch 29: LearningRateScheduler setting learning rate to 1.3999999999999998e-07.
# Epoch 29/100
# 10/10 [==============================] - 3s 309ms/step - loss: 7.0056 - mae: 7.4906 - lr: 1.4000e-07
#
# Epoch 30: LearningRateScheduler setting learning rate to 1.45e-07.
# Epoch 30/100
# 10/10 [==============================] - 3s 306ms/step - loss: 6.8647 - mae: 7.3494 - lr: 1.4500e-07
#
# Epoch 31: LearningRateScheduler setting learning rate to 1.5e-07.
# Epoch 31/100
# 10/10 [==============================] - 3s 306ms/step - loss: 6.7318 - mae: 7.2160 - lr: 1.5000e-07
#
# Epoch 32: LearningRateScheduler setting learning rate to 1.55e-07.
# Epoch 32/100
# 10/10 [==============================] - 3s 308ms/step - loss: 6.6021 - mae: 7.0859 - lr: 1.5500e-07
#
# Epoch 33: LearningRateScheduler setting learning rate to 1.6e-07.
# Epoch 33/100
# 10/10 [==============================] - 3s 308ms/step - loss: 6.4761 - mae: 6.9598 - lr: 1.6000e-07
#
# Epoch 34: LearningRateScheduler setting learning rate to 1.6499999999999998e-07.
# Epoch 34/100
# 10/10 [==============================] - 3s 308ms/step - loss: 6.3542 - mae: 6.8376 - lr: 1.6500e-07
#
# Epoch 35: LearningRateScheduler setting learning rate to 1.7e-07.
# Epoch 35/100
# 10/10 [==============================] - 3s 313ms/step - loss: 6.2341 - mae: 6.7170 - lr: 1.7000e-07
#
# Epoch 36: LearningRateScheduler setting learning rate to 1.75e-07.
# Epoch 36/100
# 10/10 [==============================] - 3s 306ms/step - loss: 6.1189 - mae: 6.6015 - lr: 1.7500e-07
#
# Epoch 37: LearningRateScheduler setting learning rate to 1.8e-07.
# Epoch 37/100
# 10/10 [==============================] - 3s 305ms/step - loss: 6.0000 - mae: 6.4818 - lr: 1.8000e-07
#
# Epoch 38: LearningRateScheduler setting learning rate to 1.85e-07.
# Epoch 38/100
# 10/10 [==============================] - 3s 312ms/step - loss: 5.8881 - mae: 6.3694 - lr: 1.8500e-07
#
# Epoch 39: LearningRateScheduler setting learning rate to 1.8999999999999998e-07.
# Epoch 39/100
# 10/10 [==============================] - 3s 301ms/step - loss: 5.7753 - mae: 6.2562 - lr: 1.9000e-07
#
# Epoch 40: LearningRateScheduler setting learning rate to 1.9499999999999999e-07.
# Epoch 40/100
# 10/10 [==============================] - 3s 303ms/step - loss: 5.6686 - mae: 6.1488 - lr: 1.9500e-07
#
# Epoch 41: LearningRateScheduler setting learning rate to 2e-07.
# Epoch 41/100
# 10/10 [==============================] - 3s 313ms/step - loss: 5.5667 - mae: 6.0468 - lr: 2.0000e-07
#
# Epoch 42: LearningRateScheduler setting learning rate to 2.0499999999999997e-07.
# Epoch 42/100
# 10/10 [==============================] - 3s 303ms/step - loss: 5.4654 - mae: 5.9450 - lr: 2.0500e-07
#
# Epoch 43: LearningRateScheduler setting learning rate to 2.1e-07.
# Epoch 43/100
# 10/10 [==============================] - 3s 310ms/step - loss: 5.3588 - mae: 5.8381 - lr: 2.1000e-07
#
# Epoch 44: LearningRateScheduler setting learning rate to 2.1499999999999998e-07.
# Epoch 44/100
# 10/10 [==============================] - 3s 307ms/step - loss: 5.2594 - mae: 5.7382 - lr: 2.1500e-07
#
# Epoch 45: LearningRateScheduler setting learning rate to 2.2e-07.
# Epoch 45/100
# 10/10 [==============================] - 3s 302ms/step - loss: 5.1642 - mae: 5.6424 - lr: 2.2000e-07
#
# Epoch 46: LearningRateScheduler setting learning rate to 2.25e-07.
# Epoch 46/100
# 10/10 [==============================] - 3s 305ms/step - loss: 5.0732 - mae: 5.5510 - lr: 2.2500e-07
#
# Epoch 47: LearningRateScheduler setting learning rate to 2.2999999999999997e-07.
# Epoch 47/100
# 10/10 [==============================] - 3s 306ms/step - loss: 4.9841 - mae: 5.4613 - lr: 2.3000e-07
#
# Epoch 48: LearningRateScheduler setting learning rate to 2.35e-07.
# Epoch 48/100
# 10/10 [==============================] - 3s 305ms/step - loss: 4.8972 - mae: 5.3742 - lr: 2.3500e-07
#
# Epoch 49: LearningRateScheduler setting learning rate to 2.4e-07.
# Epoch 49/100
# 10/10 [==============================] - 3s 310ms/step - loss: 4.8083 - mae: 5.2849 - lr: 2.4000e-07
#
# Epoch 50: LearningRateScheduler setting learning rate to 2.45e-07.
# Epoch 50/100
# 10/10 [==============================] - 3s 305ms/step - loss: 4.7263 - mae: 5.2022 - lr: 2.4500e-07
#
# Epoch 51: LearningRateScheduler setting learning rate to 2.5e-07.
# Epoch 51/100
# 10/10 [==============================] - 3s 310ms/step - loss: 4.6453 - mae: 5.1203 - lr: 2.5000e-07
#
# Epoch 52: LearningRateScheduler setting learning rate to 2.55e-07.
# Epoch 52/100
# 10/10 [==============================] - 3s 308ms/step - loss: 4.5728 - mae: 5.0474 - lr: 2.5500e-07
#
# Epoch 53: LearningRateScheduler setting learning rate to 2.6e-07.
# Epoch 53/100
# 10/10 [==============================] - 3s 313ms/step - loss: 4.5005 - mae: 4.9751 - lr: 2.6000e-07
#
# Epoch 54: LearningRateScheduler setting learning rate to 2.65e-07.
# Epoch 54/100
# 10/10 [==============================] - 3s 310ms/step - loss: 4.4342 - mae: 4.9088 - lr: 2.6500e-07
#
# Epoch 55: LearningRateScheduler setting learning rate to 2.7e-07.
# Epoch 55/100
# 10/10 [==============================] - 3s 312ms/step - loss: 4.3582 - mae: 4.8324 - lr: 2.7000e-07
#
# Epoch 56: LearningRateScheduler setting learning rate to 2.75e-07.
# Epoch 56/100
# 10/10 [==============================] - 3s 310ms/step - loss: 4.2793 - mae: 4.7528 - lr: 2.7500e-07
#
# Epoch 57: LearningRateScheduler setting learning rate to 2.7999999999999997e-07.
# Epoch 57/100
# 10/10 [==============================] - 3s 307ms/step - loss: 4.2067 - mae: 4.6796 - lr: 2.8000e-07
#
# Epoch 58: LearningRateScheduler setting learning rate to 2.8499999999999997e-07.
# Epoch 58/100
# 10/10 [==============================] - 3s 313ms/step - loss: 4.1424 - mae: 4.6153 - lr: 2.8500e-07
#
# Epoch 59: LearningRateScheduler setting learning rate to 2.9e-07.
# Epoch 59/100
# 10/10 [==============================] - 3s 308ms/step - loss: 4.0789 - mae: 4.5516 - lr: 2.9000e-07
#
# Epoch 60: LearningRateScheduler setting learning rate to 2.95e-07.
# Epoch 60/100
# 10/10 [==============================] - 3s 311ms/step - loss: 4.0109 - mae: 4.4831 - lr: 2.9500e-07
#
# Epoch 61: LearningRateScheduler setting learning rate to 3e-07.
# Epoch 61/100
# 10/10 [==============================] - 3s 309ms/step - loss: 3.9482 - mae: 4.4201 - lr: 3.0000e-07
#
# Epoch 62: LearningRateScheduler setting learning rate to 3.05e-07.
# Epoch 62/100
# 10/10 [==============================] - 3s 309ms/step - loss: 3.8849 - mae: 4.3562 - lr: 3.0500e-07
#
# Epoch 63: LearningRateScheduler setting learning rate to 3.1e-07.
# Epoch 63/100
# 10/10 [==============================] - 4s 312ms/step - loss: 3.8209 - mae: 4.2916 - lr: 3.1000e-07
#
# Epoch 64: LearningRateScheduler setting learning rate to 3.15e-07.
# Epoch 64/100
# 10/10 [==============================] - 3s 314ms/step - loss: 3.7647 - mae: 4.2354 - lr: 3.1500e-07
#
# Epoch 65: LearningRateScheduler setting learning rate to 3.2e-07.
# Epoch 65/100
# 10/10 [==============================] - 3s 315ms/step - loss: 3.7095 - mae: 4.1798 - lr: 3.2000e-07
#
# Epoch 66: LearningRateScheduler setting learning rate to 3.2499999999999996e-07.
# Epoch 66/100
# 10/10 [==============================] - 3s 315ms/step - loss: 3.6519 - mae: 4.1216 - lr: 3.2500e-07
#
# Epoch 67: LearningRateScheduler setting learning rate to 3.2999999999999996e-07.
# Epoch 67/100
# 10/10 [==============================] - 3s 313ms/step - loss: 3.5948 - mae: 4.0640 - lr: 3.3000e-07
#
# Epoch 68: LearningRateScheduler setting learning rate to 3.3499999999999997e-07.
# Epoch 68/100
# 10/10 [==============================] - 3s 313ms/step - loss: 3.5451 - mae: 4.0142 - lr: 3.3500e-07
#
# Epoch 69: LearningRateScheduler setting learning rate to 3.4e-07.
# Epoch 69/100
# 10/10 [==============================] - 3s 316ms/step - loss: 3.4962 - mae: 3.9649 - lr: 3.4000e-07
#
# Epoch 70: LearningRateScheduler setting learning rate to 3.45e-07.
# Epoch 70/100
# 10/10 [==============================] - 3s 317ms/step - loss: 3.4432 - mae: 3.9116 - lr: 3.4500e-07
#
# Epoch 71: LearningRateScheduler setting learning rate to 3.5e-07.
# Epoch 71/100
# 10/10 [==============================] - 3s 313ms/step - loss: 3.3912 - mae: 3.8590 - lr: 3.5000e-07
#
# Epoch 72: LearningRateScheduler setting learning rate to 3.55e-07.
# Epoch 72/100
# 10/10 [==============================] - 3s 312ms/step - loss: 3.3482 - mae: 3.8160 - lr: 3.5500e-07
#
# Epoch 73: LearningRateScheduler setting learning rate to 3.6e-07.
# Epoch 73/100
# 10/10 [==============================] - 3s 315ms/step - loss: 3.3020 - mae: 3.7695 - lr: 3.6000e-07
#
# Epoch 74: LearningRateScheduler setting learning rate to 3.65e-07.
# Epoch 74/100
# 10/10 [==============================] - 3s 315ms/step - loss: 3.2576 - mae: 3.7252 - lr: 3.6500e-07
#
# Epoch 75: LearningRateScheduler setting learning rate to 3.7e-07.
# Epoch 75/100
# 10/10 [==============================] - 3s 316ms/step - loss: 3.2160 - mae: 3.6833 - lr: 3.7000e-07
#
# Epoch 76: LearningRateScheduler setting learning rate to 3.75e-07.
# Epoch 76/100
# 10/10 [==============================] - 3s 315ms/step - loss: 3.1734 - mae: 3.6406 - lr: 3.7500e-07
#
# Epoch 77: LearningRateScheduler setting learning rate to 3.7999999999999996e-07.
# Epoch 77/100
# 10/10 [==============================] - 3s 314ms/step - loss: 3.1373 - mae: 3.6043 - lr: 3.8000e-07
#
# Epoch 78: LearningRateScheduler setting learning rate to 3.8499999999999997e-07.
# Epoch 78/100
# 10/10 [==============================] - 4s 315ms/step - loss: 3.0995 - mae: 3.5658 - lr: 3.8500e-07
#
# Epoch 79: LearningRateScheduler setting learning rate to 3.8999999999999997e-07.
# Epoch 79/100
# 10/10 [==============================] - 5s 427ms/step - loss: 3.0677 - mae: 3.5340 - lr: 3.9000e-07
#
# Epoch 80: LearningRateScheduler setting learning rate to 3.95e-07.
# Epoch 80/100
# 10/10 [==============================] - 3s 312ms/step - loss: 3.0306 - mae: 3.4962 - lr: 3.9500e-07
#
# Epoch 81: LearningRateScheduler setting learning rate to 4e-07.
# Epoch 81/100
# 10/10 [==============================] - 3s 316ms/step - loss: 2.9999 - mae: 3.4652 - lr: 4.0000e-07
#
# Epoch 82: LearningRateScheduler setting learning rate to 4.05e-07.
# Epoch 82/100
# 10/10 [==============================] - 4s 319ms/step - loss: 2.9697 - mae: 3.4348 - lr: 4.0500e-07
#
# Epoch 83: LearningRateScheduler setting learning rate to 4.0999999999999994e-07.
# Epoch 83/100
# 10/10 [==============================] - 3s 311ms/step - loss: 2.9404 - mae: 3.4054 - lr: 4.1000e-07
#
# Epoch 84: LearningRateScheduler setting learning rate to 4.15e-07.
# Epoch 84/100
# 10/10 [==============================] - 3s 319ms/step - loss: 2.9148 - mae: 3.3797 - lr: 4.1500e-07
#
# Epoch 85: LearningRateScheduler setting learning rate to 4.2e-07.
# Epoch 85/100
# 10/10 [==============================] - 3s 315ms/step - loss: 2.8884 - mae: 3.3532 - lr: 4.2000e-07
#
# Epoch 86: LearningRateScheduler setting learning rate to 4.2499999999999995e-07.
# Epoch 86/100
# 10/10 [==============================] - 3s 315ms/step - loss: 2.8623 - mae: 3.3267 - lr: 4.2500e-07
#
# Epoch 87: LearningRateScheduler setting learning rate to 4.2999999999999996e-07.
# Epoch 87/100
# 10/10 [==============================] - 3s 311ms/step - loss: 2.8380 - mae: 3.3023 - lr: 4.3000e-07
#
# Epoch 88: LearningRateScheduler setting learning rate to 4.3499999999999996e-07.
# Epoch 88/100
# 10/10 [==============================] - 3s 312ms/step - loss: 2.8131 - mae: 3.2774 - lr: 4.3500e-07
#
# Epoch 89: LearningRateScheduler setting learning rate to 4.4e-07.
# Epoch 89/100
# 10/10 [==============================] - 3s 309ms/step - loss: 2.7959 - mae: 3.2602 - lr: 4.4000e-07
#
# Epoch 90: LearningRateScheduler setting learning rate to 4.45e-07.
# Epoch 90/100
# 10/10 [==============================] - 4s 321ms/step - loss: 2.7743 - mae: 3.2381 - lr: 4.4500e-07
#
# Epoch 91: LearningRateScheduler setting learning rate to 4.5e-07.
# Epoch 91/100
# 10/10 [==============================] - 4s 316ms/step - loss: 2.7496 - mae: 3.2138 - lr: 4.5000e-07
#
# Epoch 92: LearningRateScheduler setting learning rate to 4.55e-07.
# Epoch 92/100
# 10/10 [==============================] - 3s 311ms/step - loss: 2.7301 - mae: 3.1937 - lr: 4.5500e-07
#
# Epoch 93: LearningRateScheduler setting learning rate to 4.5999999999999994e-07.
# Epoch 93/100
# 10/10 [==============================] - 3s 311ms/step - loss: 2.7067 - mae: 3.1701 - lr: 4.6000e-07
#
# Epoch 94: LearningRateScheduler setting learning rate to 4.65e-07.
# Epoch 94/100
# 10/10 [==============================] - 3s 308ms/step - loss: 2.6870 - mae: 3.1503 - lr: 4.6500e-07
#
# Epoch 95: LearningRateScheduler setting learning rate to 4.7e-07.
# Epoch 95/100
# 10/10 [==============================] - 3s 308ms/step - loss: 2.6679 - mae: 3.1311 - lr: 4.7000e-07
#
# Epoch 96: LearningRateScheduler setting learning rate to 4.75e-07.
# Epoch 96/100
# 10/10 [==============================] - 3s 310ms/step - loss: 2.6517 - mae: 3.1148 - lr: 4.7500e-07
#
# Epoch 97: LearningRateScheduler setting learning rate to 4.8e-07.
# Epoch 97/100
# 10/10 [==============================] - 3s 309ms/step - loss: 2.6322 - mae: 3.0947 - lr: 4.8000e-07
#
# Epoch 98: LearningRateScheduler setting learning rate to 4.849999999999999e-07.
# Epoch 98/100
# 10/10 [==============================] - 3s 309ms/step - loss: 2.6165 - mae: 3.0793 - lr: 4.8500e-07
#
# Epoch 99: LearningRateScheduler setting learning rate to 4.9e-07.
# Epoch 99/100
# 10/10 [==============================] - 3s 308ms/step - loss: 2.5986 - mae: 3.0609 - lr: 4.9000e-07
#
# Epoch 100: LearningRateScheduler setting learning rate to 4.95e-07.
# Epoch 100/100
# 10/10 [==============================] - 3s 310ms/step - loss: 2.5814 - mae: 3.0436 - lr: 4.9500e-07

# %% [markdown]
# # 6. Actualización del learning rate según los resultados obtenidos del primer entrenamiento de la red neuronal

# %% [markdown]
# Después del entrenamiento de la red neuronal se ve que learning rate resultante es de 1e-5. Se visualizará gráficamente para entender el motivo por el que se ha usado ese valor. En la gráfica se puede ver cómo el learning rate con el que menos loss hay es 1e-5, y por ese motivo, se debe volver a entrenar la red neuronal con dicho learning rate.

# %%
plt.semilogx(history.history["lr"], history.history["loss"])
plt.axis([1e-8, 1e-4, 0, 60])
# Out:
# (1e-08, 0.0001, 0.0, 60.0)

# %% [markdown]
# Se vuelve a inicializar la sesión de entrenamiento y la variable train_set:

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(51)
np.random.seed(51)
train_set = windowed_dataset(x_train, window_size=60, batch_size=100, shuffle_buffer=shuffle_buffer_size)

# %% [markdown]
# **Ejercicio 6 (0.5 puntos)**: Para crear el nuevo modelo, reutiliza la red neuronal diseñada en el ejercicio 4, pero esta vez utilizando 60 filtros en la capa de convolución.

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv1D(filters=60, kernel_size=5,
                      strides=1, padding="causal",
                      activation="relu",
                      input_shape=[None, 1]),
  tf.keras.layers.LSTM(64, return_sequences=True),
  tf.keras.layers.LSTM(64, return_sequences=True),
  tf.keras.layers.Dense(30),
  tf.keras.layers.Dense(10),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 400)
])

# %% [markdown]
# **Ejercicio 7 (0.5 puntos)**: Se debe volver a compilar la red neuronal de manera análoga a la del ejercicio 5, pero esta vez utilizar un learning rate obtenido de la función callback.

# %%
## tu código para compilar la red neuronal para el ejercicio 7 aquí
lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-8 * 10 * (epoch / 20), verbose=1)

model.compile(loss=tf.keras.losses.Huber(),
              optimizer=tf.keras.optimizers.SGD(learning_rate=1e-8, momentum=0.9),
              metrics=["mae"])

# %%
history = model.fit(train_set,epochs=150)
# Out:
# Epoch 1/150
# 25/25 [==============================] - 7s 129ms/step - loss: 127.6282 - mae: 128.1280
# Epoch 2/150
# 25/25 [==============================] - 3s 126ms/step - loss: 73.7017 - mae: 74.2009
# Epoch 3/150
# 25/25 [==============================] - 3s 129ms/step - loss: 39.7965 - mae: 40.2928
# Epoch 4/150
# 25/25 [==============================] - 3s 128ms/step - loss: 34.1677 - mae: 34.6652
# Epoch 5/150
# 25/25 [==============================] - 3s 128ms/step - loss: 31.0910 - mae: 31.5882
# Epoch 6/150
# 25/25 [==============================] - 3s 128ms/step - loss: 28.3184 - mae: 28.8153
# Epoch 7/150
# 25/25 [==============================] - 3s 129ms/step - loss: 25.8286 - mae: 26.3251
# Epoch 8/150
# 25/25 [==============================] - 3s 129ms/step - loss: 23.6035 - mae: 24.0991
# Epoch 9/150
# 25/25 [==============================] - 3s 127ms/step - loss: 21.6310 - mae: 22.1258
# Epoch 10/150
# 25/25 [==============================] - 3s 126ms/step - loss: 19.9048 - mae: 20.3984
# Epoch 11/150
# 25/25 [==============================] - 3s 129ms/step - loss: 18.3980 - mae: 18.8905
# Epoch 12/150
# 25/25 [==============================] - 3s 129ms/step - loss: 17.0694 - mae: 17.5608
# Epoch 13/150
# 25/25 [==============================] - 3s 130ms/step - loss: 15.9041 - mae: 16.3946
# Epoch 14/150
# 25/25 [==============================] - 3s 127ms/step - loss: 14.8925 - mae: 15.3829
# Epoch 15/150
# 25/25 [==============================] - 3s 127ms/step - loss: 14.0080 - mae: 14.4975
# Epoch 16/150
# 25/25 [==============================] - 3s 131ms/step - loss: 13.2387 - mae: 13.7281
# Epoch 17/150
# 25/25 [==============================] - 4s 132ms/step - loss: 12.5642 - mae: 13.0534
# Epoch 137/150
# 25/25 [==============================] - 3s 129ms/step - loss: 3.5740 - mae: 4.0438
# Epoch 138/150
# 25/25 [==============================] - 3s 132ms/step - loss: 3.5667 - mae: 4.0366
# Epoch 139/150
# 25/25 [==============================] - 3s 130ms/step - loss: 3.5582 - mae: 4.0280
# Epoch 140/150
# 25/25 [==============================] - 3s 130ms/step - loss: 3.5503 - mae: 4.0202
# Epoch 141/150
# 25/25 [==============================] - 3s 128ms/step - loss: 3.5427 - mae: 4.0125
# Epoch 142/150
# 25/25 [==============================] - 3s 130ms/step - loss: 3.5360 - mae: 4.0059
# Epoch 143/150
# 25/25 [==============================] - 3s 129ms/step - loss: 3.5279 - mae: 3.9977
# Epoch 144/150
# 25/25 [==============================] - 3s 131ms/step - loss: 3.5200 - mae: 3.9900
# Epoch 145/150
# 25/25 [==============================] - 4s 132ms/step - loss: 3.5135 - mae: 3.9833
# Epoch 146/150
# 25/25 [==============================] - 3s 127ms/step - loss: 3.5059 - mae: 3.9757
# Epoch 147/150
# 25/25 [==============================] - 4s 132ms/step - loss: 3.4998 - mae: 3.9697
# Epoch 148/150
# 25/25 [==============================] - 3s 127ms/step - loss: 3.4929 - mae: 3.9628
# Epoch 149/150
# 25/25 [==============================] - 4s 134ms/step - loss: 3.4854 - mae: 3.9553
# Epoch 150/150
# 25/25 [==============================] - 3s 130ms/step - loss: 3.4781 - mae: 3.9478

# %% [markdown]
# # 7. Predicción de los siguientes valores de la serie temporal

# %% [markdown]
# Para concluir la actividad, se usa el método model_forecast que se ha diseñado utilizando el método de la ventana temporal para hacer el nuevo metodo rnn_forecast con el cual se calcularán los nuevos valores de la serie temporal. Posteriormente, se pinta una gráfica para ver esos resultados y comprobar de forma visual que son correctos. Además, se dan los resultados de esas predicciones en forma númerica, de esta forma, este modelo diseñado en esta actividad podría ser el input de un nuevo algoritmo si fuera necesario.

# %%
rnn_forecast = model_forecast(model, series[..., np.newaxis], window_size)
rnn_forecast = rnn_forecast[split_time - window_size:-1, -1, 0]

# %%
plt.figure(figsize=(10, 6))
plot_series(time_valid, x_valid)
plot_series(time_valid, rnn_forecast)

# %%
tf.keras.metrics.mean_absolute_error(x_valid, rnn_forecast).numpy()
# Out:
# 2.5291584

# %%
print(rnn_forecast)
# Out:
# [17.023851 12.896352 12.081763 ... 13.838852 14.074747 16.063948]

# %% [markdown]
# # 8. Mostrar gráficamente los resultados.
#
# Una vez obtenido el resultado de la actividad, se procede a revisr de forma gráfica el training y validation loss a lo largo de los epochs en este nuevo entrenamiento con el learning rate optimizado.

# %%
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Recuperar una lista de resultados de la lista de datos de entrenamiento y pruebas para cada epoch de entrenamiento
#-----------------------------------------------------------
mae=history.history['mae']
loss=history.history['loss']

epochs=range(len(loss)) # Get number of epochs

# %% [markdown]
# A continuación se realiza el plot de la pérdida frente a los epochs

# %%
#------------------------------------------------
# Pérdida de entrenamiento y validación por epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r')
plt.title('Training loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Loss"])
plt.show()

# %% [markdown]
# **Ejercicio 8 (0.5 punto)**: Utilizando las 2 nuevas variables zoomed_loss y zoomed_epochs y con base en el código anterior, hacer el plot del loss frente a los epochs entre los epoch 20 y 150 para ver como va oscilando y no es un proceso lineal como podria parecer según el anterior plot.

# %%
#------------------------------------------------
# Pérdida de entrenamiento y validación por epoch con zoom
#------------------------------------------------
zoomed_loss = loss[20:]
zoomed_epochs = range(20,150)
#
## tu código para el plot con zoom del ejercicio 8 aquí
plt.plot(zoomed_epochs, zoomed_loss)
plt.show()
